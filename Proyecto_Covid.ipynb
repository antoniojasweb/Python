# %% [markdown]
# # 📚 Caso de Estudio: Predicción de Hospitalizaciones por COVID-19 en Los Ángeles
#
# ## Introducción
#
# A medida que el mundo enfrentaba las consecuencias de la pandemia de COVID-19, los sistemas de salud se vieron abrumados por el creciente número de personas infectadas. Gobiernos de todos los niveles –federal, estatal y local– debieron tomar decisiones estratégicas para apoyar a los hospitales en su respuesta a la crisis sanitaria.
#
# La analítica de datos y las tecnologías de bases de datos jugaron un papel crucial al proporcionar información en tiempo real para la toma de decisiones. Un ejemplo de esto es el panel de control público del condado de Los Ángeles, en California, que mostraba el estado actualizado de la pandemia.
#
# En este caso de estudio, nos centraremos en un ejemplo de análisis de datos que puede aportar un valor significativo a un gobierno local. Trabajaremos con datos históricos del condado de Los Ángeles (LA County), el más poblado de EE.UU., con aproximadamente 10 millones de residentes.
#
# ---
#
# ## Audiencia de los Resultados
#
# El "público objetivo" de este análisis son los departamentos de salud pública y las autoridades gubernamentales locales del Condado de Los Ángeles. Estas instituciones necesitan prever la carga hospitalaria para poder asignar recursos de forma eficiente, planificar refuerzos y tomar decisiones de política sanitaria basadas en datos.
#
# El análisis busca proporcionar predicciones claras y prácticas sobre la evolución de las hospitalizaciones, lo que permitirá anticiparse a nuevas olas de contagio y optimizar la respuesta hospitalaria.
#
# ---
#
# ## Objetivo del Caso de Estudio
#
# El objetivo principal es construir un modelo predictivo que permita anticipar el número de pacientes que necesitarán hospitalización en el Condado de Los Ángeles **dos semanas** después del momento actual, basándose en datos históricos.
#
# Para ello, realizaremos las siguientes tareas:
#
# - Limpieza y preprocesamiento de datos históricos de casos de COVID-19 y hospitalizaciones.
# - Análisis exploratorio de las tendencias y patrones de los datos. Es muy importante analizar si un condado tiende al republicanismo o si es demócrata.
# - Construcción y entrenamiento de un modelo de Machine Learning para predecir hospitalizaciones a 14 días vista. (Se os proporcionará esta parte del código en caso de no saber confeccionarla)
# - Evaluación del rendimiento del modelo mediante métricas adecuadas (RMSE, MAE, etc.). (Se os proporcionará esta parte del código en caso de no saber confeccionarla)
# - Interpretación de los resultados para apoyar la toma de decisiones de las autoridades sanitarias.
#
# Este caso de estudio permitirá aplicar técnicas de limpieza, visualización, modelado predictivo y evaluación de modelos en un contexto real de alto impacto social.
